# %% [markdown]
# <a href="https://colab.research.google.com/github/dhairyachandra/CS5542-Big-Data-Analytics-and-Applications/blob/master/ICP%201/ICP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas library

import pandas as pd

# %%
# Accessing data from google drive

path = '/content/drive/My Drive/DC Data (Unlimited)/Study/Big Data Programming/Data/Data.csv'
df = pd.read_csv(path)
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#Display summary of numeric values in dataset

df.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
# Displaying first 10 elements in data frame

df.head(10)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
# 5    843786         M  ...                  0.12440          NaN
# 6    844359         M  ...                  0.08368          NaN
# 7  84458202         M  ...                  0.11510          NaN
# 8    844981         M  ...                  0.10720          NaN
# 9  84501001         M  ...                  0.20750          NaN
#
# [10 rows x 33 columns]

# %%
# For displaying specific coulumn from Data

df[['diagnosis', 'area_worst']]
# Out:
#     diagnosis  area_worst
# 0           M      2019.0
# 1           M      1956.0
# 2           M      1709.0
# 3           M       567.7
# 4           M      1575.0
# ..        ...         ...
# 564         M      2027.0
# 565         M      1731.0
# 566         M      1124.0
# 567         M      1821.0
# 568         B       268.6
#
# [569 rows x 2 columns]

# %%
# Displaying last 10 elements in data frame

df.tail(10)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 559  925291         B  ...                  0.08732          NaN
# 560  925292         B  ...                  0.08321          NaN
# 561  925311         B  ...                  0.05905          NaN
# 562  925622         M  ...                  0.14090          NaN
# 563  926125         M  ...                  0.09873          NaN
# 564  926424         M  ...                  0.07115          NaN
# 565  926682         M  ...                  0.06637          NaN
# 566  926954         M  ...                  0.07820          NaN
# 567  927241         M  ...                  0.12400          NaN
# 568   92751         B  ...                  0.07039          NaN
#
# [10 rows x 33 columns]
